# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (30, 30)

df_barrios = gpd.read_file('./Datasets/barrios_clock.geojson')

ax = df_barrios.plot(color='blue')
