# %%
import pandas as pd

airbnb_2015 = pd.read_excel('barrios_airbnb-bogota-2015-2019.xlsx', sheet_name='2015', dtype={'Cod_Barrio': object})
airbnb_2016 = pd.read_excel('barrios_airbnb-bogota-2015-2019.xlsx', sheet_name='2016', dtype={'Cod_Barrio': object})
airbnb_2017 = pd.read_excel('barrios_airbnb-bogota-2015-2019.xlsx', sheet_name='2017', dtype={'Cod_Barrio': object})
airbnb_2018 = pd.read_excel('barrios_airbnb-bogota-2015-2019.xlsx', sheet_name='2018', dtype={'Cod_Barrio': object})
airbnb_2019 = pd.read_excel('barrios_airbnb-bogota-2015-2019.xlsx', sheet_name='2019', dtype={'Cod_Barrio': object})

# %%
airbnb_2015.head()
# Out:
#   Cod_Barrio         Barrio  Vigencia Fecha_Corte   Tipo_AlojM  \
# 0     001424  BARCELONA SUR      2015     05/2015  Apartamento
# 1     003101     LA ALAMEDA      2015     05/2015  Apartamento
# 2     003102     LAS NIEVES      2015     05/2015  Apartamento
# 3     003103      LAS AGUAS      2015     05/2015  Apartamento
# 4     003104   LA CONCORDIA      2015     05/2015  Apartamento
#
#         Tipo_AlquM  HabitacionesP   Tasa_O2  Ingreso_USDS  Ingreso_Hab_Dia  \
# 0  Entire home/apt       3.000000  0.064516         560.0       560.000000
# 1  Entire home/apt       2.000000  0.434783         484.0       242.000000
# 2     Private room       1.142857  0.537572        3674.7       524.957143
# 3     Private room       1.166667  0.358974        1726.0       287.666667
# 4  Entire home/apt       0.750000  0.322581        1923.0       480.750000
#
#    ...  Calif-LimpiezaP  Calif_LocalizaciónP  Calif_ValoresP  MascotasM  \
# ...

# %%
airbnb_2016.head()
# Out:
#   Cod_Barrio             Barrio  Vigencia Fecha_Corte            Tipo_AlojM  \
# 0     001203            CARACAS      2016     11/2016  Propiedad Compartida
# 1     001203            CARACAS      2016     12/2016  Propiedad Compartida
# 2     001204  CIUDAD JARDIN SUR      2016     05/2016                 Hotel
# 3     001204  CIUDAD JARDIN SUR      2016     06/2016                 Hotel
# 4     001205            SOCIEGO      2016     11/2016           Apartamento
#
#         Tipo_AlquM  HabitacionesP   Tasa_O2  Ingreso_USDS  Ingreso_Hab_Dia  \
# 0  Entire home/apt            1.0  0.100000         102.0            102.0
# 1  Entire home/apt            1.0  0.258065         323.0            323.0
# 2     Private room            1.0  0.032258          13.0             13.0
# 3     Private room            1.0  0.033333          13.0             13.0
# 4     Private room            1.0  0.366667         121.0            121.0
#
# ...

# %%
airbnb_2017.head()
# Out:
#   Cod_Barrio             Barrio  Vigencia Fecha_Corte            Tipo_AlojM  \
# 0     001102       BUENOS AIRES      2017     11/2017           Apartamento
# 1     001102       BUENOS AIRES      2017     12/2017           Apartamento
# 2     001108  SAN CRISTOBAL SUR      2017     11/2017           Apartamento
# 3     001202       CIUDAD BERNA      2017     06/2017           Apartamento
# 4     001203            CARACAS      2017     01/2017  Propiedad Compartida
#
#         Tipo_AlquM  HabitacionesP   Tasa_O2  Ingreso_USDS  Ingreso_Hab_Dia  \
# 0  Entire home/apt            1.0  0.333333        115.86           115.86
# 1  Entire home/apt            1.0  0.612903        220.14           220.14
# 2     Private room            1.0  0.066667         20.00            20.00
# 3     Private room            1.0  0.166667         75.00            75.00
# 4  Entire home/apt            1.0  0.096774        129.00           129.00
#
# ...

# %%
airbnb_2018.head()
# Out:
#   Cod_Barrio        Barrio  Vigencia Fecha_Corte   Tipo_AlojM  \
# 0     001101    LAS BRISAS      2018     04/2018  Apartamento
# 1     001101    LAS BRISAS      2018     08/2018  Apartamento
# 2     001101    LAS BRISAS      2018     09/2018         Casa
# 3     001101    LAS BRISAS      2018     10/2018  Apartamento
# 4     001102  BUENOS AIRES      2018     01/2018  Apartamento
#
#         Tipo_AlquM  HabitacionesP   Tasa_O2  Ingreso_USDS  Ingreso_Hab_Dia  \
# 0     Private room            2.0  0.142857          30.0             30.0
# 1     Private room            1.0  0.032258          12.0             12.0
# 2     Private room            1.0  0.033333          10.0             10.0
# 3     Private room            1.0  0.034483          17.0             17.0
# 4  Entire home/apt            1.0  0.129032          62.0             62.0
#
#    ...  Calif-LimpiezaP  Calif_LocalizaciónP  Calif_ValoresP  MascotasM  \
# ...

# %%
airbnb_2019.head()
# Out:
#   Cod_Barrio             Barrio  Vigencia Fecha_Corte   Tipo_AlojM  \
# 0     001101         LAS BRISAS      2019  2019-01-01  Apartamento
# 1     001101         LAS BRISAS      2019  2019-02-01  Apartamento
# 2     001102       BUENOS AIRES      2019  2019-01-01  Apartamento
# 3     001102       BUENOS AIRES      2019  2019-02-01  Apartamento
# 4     001108  SAN CRISTOBAL SUR      2019  2019-01-01         Casa
#
#      Tipo_AlquM  HabitacionesP   Tasa_O2  Ingreso_USDS  Ingreso_Hab_Dia  ...  \
# 0  Private room       1.000000  0.032258         18.00        18.000000  ...
# 1  Private room       1.000000  0.035714         18.00        18.000000  ...
# 2  Private room       1.000000  0.064516         37.00        37.000000  ...
# 3  Private room       1.666667  0.083333         96.67       125.766421  ...
# 4  Private room       1.000000  0.032258         51.83        51.830000  ...
#
#    Calif-LimpiezaP  Calif_LocalizaciónP  Calif_ValoresP  MascotasM  \
# ...

# %%
airbnb = pd.concat([airbnb_2015, airbnb_2016, airbnb_2017, airbnb_2018, airbnb_2019])
airbnb.shape
# Out:
# (53452, 32)

# %%
airbnb.head()
# Out:
#   Cod_Barrio         Barrio  Vigencia Fecha_Corte   Tipo_AlojM  \
# 0     001424  BARCELONA SUR      2015     05/2015  Apartamento
# 1     003101     LA ALAMEDA      2015     05/2015  Apartamento
# 2     003102     LAS NIEVES      2015     05/2015  Apartamento
# 3     003103      LAS AGUAS      2015     05/2015  Apartamento
# 4     003104   LA CONCORDIA      2015     05/2015  Apartamento
#
#         Tipo_AlquM  HabitacionesP   Tasa_O2  Ingreso_USDS  Ingreso_Hab_Dia  \
# 0  Entire home/apt       3.000000  0.064516         560.0       560.000000
# 1  Entire home/apt       2.000000  0.434783         484.0       242.000000
# 2     Private room       1.142857  0.537572        3674.7       524.957143
# 3     Private room       1.166667  0.358974        1726.0       287.666667
# 4  Entire home/apt       0.750000  0.322581        1923.0       480.750000
#
#    ...  Calif-LimpiezaP  Calif_LocalizaciónP  Calif_ValoresP  MascotasM  \
# ...

# %%
def get_unique_id(row):
    tipo = str(row['Tipo_AlojM'])
    max_h = str(row['Max_HuéspedesP'])
    ban = str(row['BañosP'])
    hab = str(row['HabitacionesP'])
    #return hash(row['Cod_Barrio'] + row['Tipo_AlojM']) + row['Tipo_AlquM'])
    return hash(row['Cod_Barrio'] + tipo)

airbnb['airbnb_id'] = airbnb.apply(get_unique_id, axis=1)

airbnb.head()
# Out:
#   Cod_Barrio         Barrio  Vigencia Fecha_Corte   Tipo_AlojM  \
# 0     001424  BARCELONA SUR      2015     05/2015  Apartamento
# 1     003101     LA ALAMEDA      2015     05/2015  Apartamento
# 2     003102     LAS NIEVES      2015     05/2015  Apartamento
# 3     003103      LAS AGUAS      2015     05/2015  Apartamento
# 4     003104   LA CONCORDIA      2015     05/2015  Apartamento
#
#         Tipo_AlquM  HabitacionesP   Tasa_O2  Ingreso_USDS  Ingreso_Hab_Dia  \
# 0  Entire home/apt       3.000000  0.064516         560.0       560.000000
# 1  Entire home/apt       2.000000  0.434783         484.0       242.000000
# 2     Private room       1.142857  0.537572        3674.7       524.957143
# 3     Private room       1.166667  0.358974        1726.0       287.666667
# 4  Entire home/apt       0.750000  0.322581        1923.0       480.750000
#
#    ...  Calif_LocalizaciónP  Calif_ValoresP  MascotasM  ComodidadesM  \
# ...
